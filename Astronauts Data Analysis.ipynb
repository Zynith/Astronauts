# %% [markdown]
# ![image.png](attachment:a1b96fea-a5eb-450a-978d-2f58d63e9a77.png)

# %% [markdown]
# # <en><center>NASA Astronauts Dataset Analysis</center></en>

# %% [markdown]
# ## <en><center>Frantz Alexander</center></en>

# %% [markdown]
# ### <en><center>November 27, 2022</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# ### <en><center>Project Introduction</center></en>

# %% [markdown]
# #### <en><center>The dataset used was obtained from the NASA official website and published as the Astronaut April 2013 fact book.</center></en>

# %% [markdown]
# #### <en><center>The goal of the project was to acquire key insights of astonauts in the human space flight program at NASA from 1959 to 2013.</center></en>

# %% [markdown]
# ## <en><center>Libraries</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('ticks')

# %matplotlib inline

# %% [markdown]
# ## <en><center>Data Preparation</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# ### Create Data Wrangling Function

# %%
def wrangle(data_set):
    """
        This function is meant to import and wrangle the dataset. 
    """
    df = pd.read_csv(data_set)   
    
    return df

# %% [markdown]
# #### Import CSV File

# %%
df = wrangle("astronauts.csv")

# %% [markdown]
# ## <en><center>Investigating the characteristics of the dataset.</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### How Many Rows and Columns are in the Dataset?

# %%
rows = df.shape[0]
columns = df.shape[1]

print("This dataset contains: {} rows and {} columns".format(rows,columns))
# Out:
# This dataset contains: 357 rows and 19 columns

# %% [markdown]
# #### What are the Column Names?

# %%
for col in df.columns:
    print(col)
# Out:
# Name
# Year
# Group
# Status
# Birth Date
# Birth Place
# Gender
# Alma Mater
# Undergraduate Major
# Graduate Major
# Military Rank
# Military Branch
# Space Flights
# Space Flight (hr)
# Space Walks
# Space Walks (hr)
# Missions
# Death Date
# Death Mission

# %% [markdown]
# #### What are the Column Data Types?

# %%
df.dtypes
# Out:
# Name                    object
# Year                   float64
# Group                  float64
# Status                  object
# Birth Date              object
# Birth Place             object
# Gender                  object
# Alma Mater              object
# Undergraduate Major     object
# Graduate Major          object
# Military Rank           object
# Military Branch         object
# Space Flights            int64
# Space Flight (hr)        int64
# Space Walks              int64
# Space Walks (hr)       float64
# Missions                object
# Death Date              object
# Death Mission           object
# dtype: object

# %% [markdown]
# #### What are the Characteristics of each Column Feature?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
#  15  Space Walks (hr)     357 non-null    float64
#  16  Missions             334 non-null    object
#  17  Death Date           52 non-null     object
#  18  Death Mission        16 non-null     object
# dtypes: float64(3), int64(3), object(13)
# memory usage: 53.1+ KB

# %% [markdown]
# #### Displaying the Number of Unique Values in each Column

# %%
df.nunique()
# Out:
# Name                   357
# Year                    20
# Group                   20
# Status                   4
# Birth Date             348
# Birth Place            272
# Gender                   2
# Alma Mater             280
# Undergraduate Major     83
# Graduate Major         143
# Military Rank           12
# Military Branch         14
# Space Flights            8
# Space Flight (hr)      270
# Space Walks             11
# Space Walks (hr)        52
# Missions               305
# Death Date              38
# Death Mission            3
# dtype: int64

# %% [markdown]
# #### Displaying the Number of Null Values in each Column

# %%
df.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %% [markdown]
# #### Display of the Percentage of Missing Values in each Column

# %%
for col in df.columns:
    percentage_missing = np.mean(df[col].isnull())
    print("{} - {}%".format(col, round(percentage_missing*100)))
# Out:
# Name - 0%
# Year - 8%
# Group - 8%
# Status - 0%
# Birth Date - 0%
# Birth Place - 0%
# Gender - 0%
# Alma Mater - 0%
# Undergraduate Major - 6%
# Graduate Major - 17%
# Military Rank - 42%
# Military Branch - 41%
# Space Flights - 0%
# Space Flight (hr) - 0%
# Space Walks - 0%
# Space Walks (hr) - 0%
# Missions - 6%
# Death Date - 85%
# Death Mission - 96%

# %% [markdown]
# #### Display of the First 5 Rows of each Column

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# 1                              STS 51-F (Challenger)        NaN           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN

# %% [markdown]
# #### The Descriptive Statstics of the Numerical Column Features

# %%
df.describe()
# Out:
#               Year       Group  Space Flights  Space Flight (hr)  Space Walks  \
# count   330.000000  330.000000     357.000000         357.000000   357.000000
# mean   1985.106061   11.409091       2.364146        1249.266106     1.246499
# std      13.216147    5.149962       1.428700        1896.759857     2.056989
# min    1959.000000    1.000000       0.000000           0.000000     0.000000
# 25%    1978.000000    8.000000       1.000000         289.000000     0.000000
# 50%    1987.000000   12.000000       2.000000         590.000000     0.000000
# 75%    1996.000000   16.000000       3.000000        1045.000000     2.000000
# max    2009.000000   20.000000       7.000000       12818.000000    10.000000
#
#        Space Walks (hr)
# count        357.000000
# mean           7.707283
# std           13.367973
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%           12.000000
# max           67.000000

# %% [markdown]
# ## <en><center>Mission Status</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### What is the Status of the Astronauts?

# %%
df["Status"].value_counts()
# Out:
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: Status, dtype: int64

# %% [markdown]
# #### Visualizing the Number of Astronauts by Status

# %%
plt.figure(figsize = (12,8))
sns.countplot(
    x = "Status", 
    data = df, 
    hue = "Gender"
)
plt.title("Number of Astronauts by Status");

# %% [markdown]
# #### Display of Astronaut Status Based on Gender

# %%
df.groupby("Gender")["Status"].value_counts()
# Out:
# Gender  Status
# Female  Retired        24
#         Active         13
#         Deceased        7
#         Management      6
# Male    Retired       196
#         Deceased       44
#         Active         37
#         Management     30
# Name: Status, dtype: int64

# %% [markdown]
# #### How Many Astronauts were of each Gender?

# %%
df["Gender"].value_counts()
# Out:
# Male      307
# Female     50
# Name: Gender, dtype: int64

# %% [markdown]
# #### Visualizing the Count of Astronauts by Gender

# %%
plt.figure(figsize = (12,8))
sns.countplot(
    x = "Gender", 
    data = df
)
plt.title("Astronaut Count by Gender");

# %% [markdown]
# #### Subset for Active Astronauts

# %%
active_mask = df["Status"] == "Active"
active_astronauts = df[active_mask]

# %% [markdown]
# #### How Many Active Astronauts are of each Gender?

# %%
active_astronauts["Gender"].value_counts()
# Out:
# Male      37
# Female    13
# Name: Gender, dtype: int64

# %% [markdown]
# #### Visualizing the Active Astronauts Count by Gender

# %%
plt.figure(figsize = (12,8))
sns.countplot(
    x = "Gender", 
    data = active_astronauts
)
plt.title("Active Astronauts Count by Gender");

# %% [markdown]
# ## <en><center>Mission Accidents</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### Create Mission Accidents Subset

# %%
accidents_mask = ~df["Death Mission"].isnull()
mission_accidents = df[accidents_mask]

# %% [markdown]
# #### Which Missions had Accidents?

# %%
for mission in mission_accidents["Death Mission"].unique():
        print(mission)
# Out:
# STS-107 (Columbia)
# Apollo 1
# STS 51-L (Challenger)

# %% [markdown]
# #### How Many Men and Women Passed Away from an Accident?

# %%
male, female = mission_accidents["Gender"].value_counts()

print("There were {} men and {} women that passed away from \
an accident in space flight.".format(male, female))
# Out:
# There were 12 men and 4 women that passed away from an accident in space flight.

# %% [markdown]
# #### How Many People Passed Away in a Space Flight Accident?

# %%
people_accidents = len(mission_accidents)

print("There were {} astronauts who passed away in space \
flight accidents throughout NASA's history.".format(people_accidents))
# Out:
# There were 16 astronauts who passed away in space flight accidents throughout NASA's history.

# %% [markdown]
# #### There were 3 missions that had accidents which resulted in the deaths of 16 astronauts:
#    - STS-107 (Columbia)
#    - Apollo 1
#    - STS 51-L (Challenger)

# %% [markdown]
# #### Who were the Astronauts who Passed Away in an Accident?

# %%
print("These brave men and women who have passed away\
have worked to make our world a better place:")

for name in mission_accidents["Name"]:
    print(name)
# Out:
# These brave men and women who have passed awayhave worked to make our world a better place:
# Michael P. Anderson
# David M. Brown
# Roger B. Chaffee
# Kalpana Chawla
# Laurel B. Clark
# Virgil I. Grissom
# Rick D. Husband
# Gregory B. Jarvis
# S. Christa McAuliffe
# William C. McCool
# Ronald E. McNair
# Ellison S. Onizuka
# Judith A. Resnik
# Francis R. Scobee
# Michael J. Smith
# Edward H. White II

# %% [markdown]
# #### Mission Accidents by Gender

# %%
pd.crosstab(
    index = mission_accidents["Gender"], 
    columns = mission_accidents["Death Mission"]
)
# Out:
# Death Mission  Apollo 1  STS 51-L (Challenger)  STS-107 (Columbia)
# Gender
# Female                0                      2                   2
# Male                  3                      5                   4

# %% [markdown]
# #### Military Ranks Value Counts

# %%
mission_accidents["Military Rank"].value_counts()
# Out:
# Lieutenant Colonel      4
# Captain                 3
# Lieutenant Commander    1
# Colonel                 1
# Commander               1
# Major                   1
# Name: Military Rank, dtype: int64

# %% [markdown]
# #### Mission Accidents by Military Branch

# %%
pd.crosstab(
    index = mission_accidents["Military Branch"], 
    columns = mission_accidents["Death Mission"]
)
# Out:
# Death Mission           Apollo 1  STS 51-L (Challenger)  STS-107 (Columbia)
# Military Branch
# US Air Force                   2                      1                   2
# US Air Force (Retired)         0                      1                   0
# US Navy                        1                      1                   3

# %% [markdown]
# ## <en><center>Military Rank</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### The List of Military Ranks

# %%
for rank in df["Military Rank"].unique():
    print(rank)
# Out:
# nan
# Colonel
# Lieutenant Colonel
# Captain
# Major General
# Commander
# Lieutenant Commander
# Brigadier General
# Major
# Lieutenant General
# Chief Warrant Officer
# Rear Admiral
# Vice Admiral

# %% [markdown]
# #### The List of Military Ranks for Active Astronauts

# %%
for rank in active_astronauts["Military Rank"].unique():
    print(rank)
# Out:
# nan
# Commander
# Colonel
# Captain

# %% [markdown]
# #### What are the Most Common Military Rank Among Astronauts?

# %%
df["Military Rank"].value_counts()
# Out:
# Colonel                  94
# Captain                  68
# Commander                13
# Lieutenant Colonel       10
# Major                     5
# Major General             4
# Brigadier General         4
# Lieutenant Commander      3
# Lieutenant General        2
# Rear Admiral              2
# Chief Warrant Officer     1
# Vice Admiral              1
# Name: Military Rank, dtype: int64

# %% [markdown]
# #### Visualizing the count of Astronauts by Military Rank

# %%
plt.figure(figsize = (12,8))
(df["Military Rank"]
     .value_counts()
     .sort_values()
     .plot(kind = "barh")
)
plt.xlabel("Count")
plt.ylabel("Military Rank")
plt.title("Count of Astronauts by Military Rank");

# %% [markdown]
# #### Who was the Highest Ranking Military Service Member who Participated in Space Flight?

# %%
vice_admiral = df[df["Military Rank"] == "Vice Admiral"]

for name in vice_admiral["Name"]:
    print("Vice Admiral {}, was the highest ranking Military\
    service member to participate in space flight.".format(name))
# Out:
# Vice Admiral Richard H. Truly, was the highest ranking Military    service member to participate in space flight.

# %% [markdown]
# #### What are the Most Commmon Military Ranks Among Active Astronauts?

# %%
active_astronauts["Military Rank"].value_counts()
# Out:
# Colonel      17
# Captain       5
# Commander     4
# Name: Military Rank, dtype: int64

# %% [markdown]
# #### Astronaut Military Rank Breakdown by Gender

# %%
pd.crosstab(
    index = df["Military Rank"], 
    columns = df["Gender"]
)
# Out:
# Gender                 Female  Male
# Military Rank
# Brigadier General           0     4
# Captain                     6    62
# Chief Warrant Officer       0     1
# Colonel                     5    89
# Commander                   1    12
# Lieutenant Colonel          0    10
# Lieutenant Commander        0     3
# Lieutenant General          1     1
# Major                       0     5
# Major General               0     4
# Rear Admiral                0     2
# Vice Admiral                0     1

# %% [markdown]
# #### Breakdown of Active Astronauts Military Ranks by Gender

# %%
pd.crosstab(
    index = active_astronauts["Military Rank"], 
    columns = active_astronauts["Gender"]
)
# Out:
# Gender         Female  Male
# Military Rank
# Captain             1     4
# Colonel             1    16
# Commander           0     4

# %% [markdown]
# #### How Many Astronauts did not Serve in the Military?

# %%
df["Military Rank"].isnull().sum()
# Out:
# 150

# %% [markdown]
# ## <en><center>Military Branch</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### Breakdown of Military Branch by Gender?

# %%
pd.crosstab(
    index = df["Military Branch"], 
    columns = df["Gender"]
)
# Out:
# Gender                           Female  Male
# Military Branch
# US Air Force                          2    19
# US Air Force (Retired)                3    58
# US Air Force Reserves                 0     2
# US Air Force Reserves (Retired)       0     3
# US Army                               0     4
# US Army (Retired)                     1    12
# US Coast Guard (Retired)              0     2
# US Marine Corps                       0     3
# US Marine Corps (Retired)             0    17
# US Marine Corps Reserves              0     2
# US Naval Reserves                     1     1
# US Naval Reserves (Retired)           0     1
# US Navy                               3    18
# US Navy (Retired)                     3    56

# %% [markdown]
# #### Space Flight statistics for each Military Branch by Gender

# %%
pd.crosstab(
    index = df["Military Branch"], 
    columns = df["Gender"],
    values = df["Space Flights"],
    aggfunc = ["mean", "std", "max"]
)
# Out:
#                                      mean                 std            \
# Gender                             Female      Male    Female      Male
# Military Branch
# US Air Force                     2.500000  1.631579  3.535534  1.011628
# US Air Force (Retired)           3.333333  2.775862  0.577350  1.351323
# US Air Force Reserves                 NaN  1.500000       NaN  0.707107
# US Air Force Reserves (Retired)       NaN  2.000000       NaN  1.000000
# US Army                               NaN  2.000000       NaN  1.414214
# US Army (Retired)                4.000000  2.416667       NaN  1.378954
# US Coast Guard (Retired)              NaN  2.500000       NaN  0.707107
# US Marine Corps                       NaN  1.000000       NaN  1.000000
# US Marine Corps (Retired)             NaN  2.588235       NaN  1.175735
# US Marine Corps Reserves              NaN  2.500000       NaN  2.121320
# US Naval Reserves                2.000000  5.000000       NaN       NaN
# US Naval Reserves (Retired)           NaN  3.000000       NaN       NaN
# US Navy                          1.666667  1.277778  0.577350  0.894792
# US Navy (Retired)                2.333333  2.875000  1.527525  1.322016
#
#                                    max
# Gender                          Female Male
# Military Branch
# US Air Force                       5.0  4.0
# US Air Force (Retired)             4.0  7.0
# US Air Force Reserves              NaN  2.0
# US Air Force Reserves (Retired)    NaN  3.0
# US Army                            NaN  3.0
# US Army (Retired)                  4.0  5.0
# US Coast Guard (Retired)           NaN  3.0
# US Marine Corps                    NaN  2.0
# US Marine Corps (Retired)          NaN  4.0
# US Marine Corps Reserves           NaN  4.0
# US Naval Reserves                  2.0  5.0
# US Naval Reserves (Retired)        NaN  3.0
# US Navy                            2.0  3.0
# US Navy (Retired)                  4.0  6.0

# %% [markdown]
# #### What Ranks did Astronauts Achieve within each Military Branch?

# %%
pd.crosstab(
    index = df["Military Branch"], 
    columns = df["Military Rank"]
)
# Out:
# Military Rank                    Brigadier General  Captain  \
# Military Branch
# US Air Force                                     0        2
# US Air Force (Retired)                           3        0
# US Air Force Reserves                            0        0
# US Air Force Reserves (Retired)                  0        0
# US Army                                          0        0
# US Army (Retired)                                1        1
# US Coast Guard (Retired)                         0        1
# US Marine Corps                                  0        0
# US Marine Corps (Retired)                        0        0
# US Marine Corps Reserves                         0        0
# US Naval Reserves                                0        1
# US Naval Reserves (Retired)                      0        1
# US Navy                                          0       12
# US Navy (Retired)                                0       50
#
# Military Rank                    Chief Warrant Officer  Colonel  Commander  \
# Military Branch
# US Air Force                                         0       11          0
# US Air Force (Retired)                               0       53          0
# US Air Force Reserves                                0        0          0
# US Air Force Reserves (Retired)                      0        1          0
# US Army                                              0        3          0
# US Army (Retired)                                    1        9          0
# US Coast Guard (Retired)                             0        0          1
# US Marine Corps                                      0        2          0
# US Marine Corps (Retired)                            0       14          0
# US Marine Corps Reserves                             0        1          0
# US Naval Reserves                                    0        0          0
# US Naval Reserves (Retired)                          0        0          0
# US Navy                                              0        0          7
# US Navy (Retired)                                    0        0          5
#
# Military Rank                    Lieutenant Colonel  Lieutenant Commander  \
# Military Branch
# US Air Force                                      5                     0
# US Air Force (Retired)                            1                     0
# US Air Force Reserves                             0                     0
# US Air Force Reserves (Retired)                   0                     0
# US Army                                           1                     0
# US Army (Retired)                                 1                     0
# US Coast Guard (Retired)                          0                     0
# US Marine Corps                                   0                     0
# US Marine Corps (Retired)                         2                     0
# US Marine Corps Reserves                          0                     0
# US Naval Reserves                                 0                     0
# US Naval Reserves (Retired)                       0                     0
# US Navy                                           0                     2
# US Navy (Retired)                                 0                     1
#
# Military Rank                    Lieutenant General  Major  Major General  \
# Military Branch
# US Air Force                                      1      2              0
# US Air Force (Retired)                            1      1              2
# US Air Force Reserves                             0      1              0
# US Air Force Reserves (Retired)                   0      0              1
# US Army                                           0      0              0
# US Army (Retired)                                 0      0              0
# US Coast Guard (Retired)                          0      0              0
# US Marine Corps                                   0      1              0
# US Marine Corps (Retired)                         0      0              1
# US Marine Corps Reserves                          0      0              0
# US Naval Reserves                                 0      0              0
# US Naval Reserves (Retired)                       0      0              0
# US Navy                                           0      0              0
# US Navy (Retired)                                 0      0              0
#
# Military Rank                    Rear Admiral  Vice Admiral
# Military Branch
# US Air Force                                0             0
# US Air Force (Retired)                      0             0
# US Air Force Reserves                       0             0
# US Air Force Reserves (Retired)             0             0
# US Army                                     0             0
# US Army (Retired)                           0             0
# US Coast Guard (Retired)                    0             0
# US Marine Corps                             0             0
# US Marine Corps (Retired)                   0             0
# US Marine Corps Reserves                    0             0
# US Naval Reserves                           0             0
# US Naval Reserves (Retired)                 0             0
# US Navy                                     0             0
# US Navy (Retired)                           2             1

# %% [markdown]
# ## <en><center>Education</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### Education Subset Function

# %%
def education_wrangle(dataframe):
    
    # Create copy of dataframe
    edu_df = dataframe.copy()
    
    # Add "Undergraduate Alma Mater" Column
    edu_df["Undergraduate Alma Mater"] = (
        edu_df["Alma Mater"].str.split(";", expand = True)[0]
    )
    
    # Add "Graduate Alma Mater" Column
    edu_df["Graduate Alma Mater"] = (
        edu_df["Alma Mater"].str.split(";", expand = True)[1]
    )
    
    # Add "Post-Graduate Alma Mater" Column
    edu_df["Post-Graduate Alma Mater"] = (
        edu_df["Alma Mater"].str.split(";", expand = True)[2]
    )
    
    # Drop old "ALma Mater" Column
    edu_df.drop(columns = ["Alma Mater"], inplace = True)
    
    return edu_df

# %%
education_df = education_wrangle(df)

# %% [markdown]
# #### List of Columns in the Education Dataframe

# %%
for col in education_df.columns:
    print(col)
# Out:
# Name
# Year
# Group
# Status
# Birth Date
# Birth Place
# Gender
# Undergraduate Major
# Graduate Major
# Military Rank
# Military Branch
# Space Flights
# Space Flight (hr)
# Space Walks
# Space Walks (hr)
# Missions
# Death Date
# Death Mission
# Undergraduate Alma Mater
# Graduate Alma Mater
# Post-Graduate Alma Mater

# %% [markdown]
# #### How Many Astronauts did not have a Graduate Degree?

# %%
graduate_degree = education_df["Graduate Major"].isnull().sum()

print("There were {} astronauts that did \
not have a graduate degree.".format(graduate_degree))
# Out:
# There were 59 astronauts that did not have a graduate degree.

# %% [markdown]
# #### What Percentage of Astronauts did not have a Graduate Degree?

# %%
graduate_percentage = (
    np.mean(education_df["Graduate Major"].isnull())
)

print("{}% of Astronauts did not\
have a Graduate Degree.".format(round(graduate_percentage*100)))
# Out:
# 17% of Astronauts did nothave a Graduate Degree.

# %% [markdown]
# #### How Many Different Types of Majors did Astonauts have?

# %%
num_majors = education_df["Undergraduate Major"].nunique()

print("Astronauts had {} unique undergraduate majors.".format(num_majors))
# Out:
# Astronauts had 83 unique undergraduate majors.

# %% [markdown]
# #### Top 10 Undergraduate Majors for Astronauts

# %%
education_df["Undergraduate Major"].value_counts().head(10)
# Out:
# Physics                     35
# Aerospace Engineering       33
# Mechanical Engineering      30
# Aeronautical Engineering    28
# Electrical Engineering      23
# Engineering Science         13
# Engineering                 12
# Mathematics                 11
# Chemistry                   10
# Chemical Engineering         9
# Name: Undergraduate Major, dtype: int64

# %% [markdown]
# #### Top 10 Universities for Undergraduate Studies

# %%
education_df["Undergraduate Alma Mater"].value_counts().head(10)
# Out:
# US Naval Academy                     52
# US Air Force Academy                 38
# US Military Academy                  18
# Purdue University                    15
# MIT                                  12
# University of Colorado                8
# Stanford University                   7
# University of Texas                   6
# University of Illinois                5
# University of California-Berkeley     5
# Name: Undergraduate Alma Mater, dtype: int64

# %% [markdown]
# #### Top 10 Universities for Graduate Studies.

# %%
education_df["Graduate Alma Mater"].value_counts().head(10)
# Out:
#  US Naval Postgraduate School          29
#  MIT                                   22
#  Stanford University                   14
#  Georgia Institute of Technology       10
#  California Institute of Technology     8
#  Purdue University                      8
#  University of Southern California      7
#  University of Tennessee                6
#  University of Colorado                 6
#  George Washington University           5
# Name: Graduate Alma Mater, dtype: int64

# %% [markdown]
# #### Top 10 Universities for Post-Graduate Studies

# %%
education_df["Post-Graduate Alma Mater"].value_counts().head(10)
# Out:
#  University of Houston-Clear Lake        5
#  University of Florida                   3
#  University of Texas                     2
#  US Naval War College                    2
#  Rice University                         2
#  Harvard University                      2
#  University of California-Los Angeles    2
#  University of Washington                2
#  University of Houston                   2
#  US Naval Postgraduate School            2
# Name: Post-Graduate Alma Mater, dtype: int64

# %% [markdown]
# ## <en><center>Space Flight</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### Subset for Space Flight Hours

# %%
space_flight_mask = df["Space Flight (hr)"] > 0
space_flights = df[space_flight_mask]

# %% [markdown]
# #### What was the Greatest Amount of Time in Space?

# %%
space_flight_max = space_flights["Space Flight (hr)"].max()

print(
    "The highest amount of time in space \
was {} hours.".format(space_flight_max)
)
# Out:
# The highest amount of time in space was 12818 hours.

# %% [markdown]
# #### Who was the Astronaut that had Spent the Most Amount of Time in Space?

# %%
for name in space_flights[space_flights["Space Flight (hr)"] == 12818]["Name"]:
    print(name + ", is the astronaut that spent the most time in space flight.")
# Out:
# Jeffrey N. Williams, is the astronaut that spent the most time in space flight.

# %% [markdown]
# #### Which Active Astronaut had the Most Space Flights?

# %%
active_space_flights = (
    space_flights[space_flights["Status"] == "Active"]
)

# %%
active_space_flights["Space Flights"].max()
# Out:
# 6

# %%
most_space_flights = (
    active_space_flights[active_space_flights["Space Flights"] == 6]
)

for name in most_space_flights["Name"]:
    print(name +", is the astronaut that performed the most space flights.")
# Out:
# C. Michael Foale, is the astronaut that performed the most space flights.

# %% [markdown]
# #### Which Astronaut has Performed the Most Space Flights?

# %%
df["Space Flights"].max()
# Out:
# 7

# %%
most_flights_mask = df["Space Flights"] == 7

print("There were {} astronauts that participated \
in the most space flights:".format(len(df[most_flights_mask])))

for name in df[most_flights_mask]["Name"]:
    print(name)
# Out:
# There were 2 astronauts that participated in the most space flights:
# Franklin R. Chang-Diaz
# Jerry L. Ross

# %% [markdown]
# #### Which Female Astronauts had the Most Space Flights?

# %%
df[df["Gender"] == "Female"]["Space Flights"].max()
# Out:
# 5

# %%
female_flights = df[
    (df["Gender"] ==  "Female") & (df["Space Flights"] == 5)
]

print("These are the Female astronauts \
who participated in the most space flights:")

for name in female_flights["Name"]:
    print(name)
# Out:
# These are the Female astronauts who participated in the most space flights:
# Bonnie J. Dunbar
# Susan J. Helms
# Marsha S. Ivins
# Tamara E. Jernigan
# Shannon W. Lucid
# Janice E. Voss

# %% [markdown]
# #### Which Active Female Astronauts had the Most Space Flights?

# %%
(
    active_space_flights
    [active_space_flights["Gender"] == "Female"]
    ["Space Flights"]
    .max()
)
# Out:
# 3

# %%
most_active_female_space_flights = active_space_flights[
    (active_space_flights["Gender"] ==  "Female") 
    & (active_space_flights["Space Flights"] ==  3)
]

print("This is a listing of the current active \
female astronauts with the most space flights:")

for name in most_active_female_space_flights["Name"]:
    print(name)
# Out:
# This is a listing of the current active female astronauts with the most space flights:
# Catherine G. Coleman
# Peggy A. Whitson
# Stephanie D. Wilson

# %% [markdown]
# #### What is the Count of Space Flights Performed?

# %%
space_flights["Space Flights"].value_counts(ascending = False)
# Out:
# 2    98
# 1    85
# 3    64
# 4    57
# 5    19
# 6     5
# 7     2
# Name: Space Flights, dtype: int64

# %% [markdown]
# #### Visualizing the Count of Space flights

# %%
sns.displot(
    space_flights["Space Flights"], 
    bins = 30, 
    color = "blue",
    height = 6,
    aspect = 1.5
)

plt.title("Count by number of Space Flights");

# %% [markdown]
# #### Visualizing the Distribution of Astronaut Space Flight Hours

# %%
space_flight_hours = space_flights["Space Flight (hr)"]

# %%
sns.displot(
    space_flight_hours, 
    bins = 30, 
    color = "blue",
    height = 6,
    aspect = 1.5, 
    alpha = 0.5
)
plt.axvline(
    np.mean(space_flight_hours), 
    ls = "--", 
    label = "Mean", 
    color = "red"
)
plt.axvline(
    np.median(space_flight_hours), 
    ls = ":", 
    label = "Median", 
    color = "green"
)
plt.legend()
plt.title("Distribution for Astronaut Space Flight (hr)");

# %% [markdown]
# #### Breakdown of Space Flights by Military Rank

# %%
pd.crosstab(
    index = space_flights["Military Rank"], 
    columns = space_flights["Space Flights"]
)
# Out:
# Space Flights           1   2   3   4  5  6  7
# Military Rank
# Brigadier General       1   2   1   0  0  0  0
# Captain                13  17  15  15  3  2  0
# Chief Warrant Officer   1   0   0   0  0  0  0
# Colonel                14  32  19  20  4  1  1
# Commander               7   3   1   0  0  0  0
# Lieutenant Colonel      2   5   3   0  0  0  0
# Lieutenant Commander    0   0   1   0  0  0  0
# Lieutenant General      0   0   0   1  1  0  0
# Major                   2   1   0   0  0  0  0
# Major General           2   1   0   1  0  0  0
# Rear Admiral            0   1   1   0  0  0  0
# Vice Admiral            0   1   0   0  0  0  0

# %% [markdown]
# #### Number of Space Flights by Gender

# %%
pd.crosstab(
    index = space_flights["Gender"], 
    columns = space_flights["Space Flights"]
)
# Out:
# Space Flights   1   2   3   4   5  6  7
# Gender
# Female         11  12  10   6   6  0  0
# Male           74  86  54  51  13  5  2

# %% [markdown]
# #### Pivot Table for Space Flights based on Gender

# %%
pd.pivot_table(
    data = space_flights,
    index = "Gender", 
    values = ["Space Flights", "Space Flight (hr)"], 
    aggfunc = ["mean","median", "std"]
)
# Out:
#                     mean                          median                \
#        Space Flight (hr) Space Flights Space Flight (hr) Space Flights
# Gender
# Female       1752.555556      2.644444               890             2
# Male         1288.150877      2.529825               614             2
#
#                      std
#        Space Flight (hr) Space Flights
# Gender
# Female       2305.561296      1.351019
# Male         1869.817804      1.325530

# %% [markdown]
# ## <en><center>Space Walks</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# #### Subset for Astronauts that have Taken Space Walks

# %%
space_walks_mask = (
    df["Space Walks (hr)"] > 0) & (df["Space Flights"] > 0
)
space_walks = df[space_walks_mask]

# %% [markdown]
# #### What was the Highest Number of Space Walks Performed?

# %%
space_walks["Space Walks"].max()
# Out:
# 10

# %% [markdown]
# #### Which Astronaut Performed the Most Space Walks?

# %%
most_space_walks = space_walks[space_walks["Space Walks"] == 10]

for name in most_space_walks["Name"]:
    print(name + ", performed the greatest number of \
    space walks at {}.".format(space_walks["Space Walks"].max()))
# Out:
# Michael E. Lopez-Alegria, performed the greatest number of     space walks at 10.

# %% [markdown]
# #### What was the most amount of time Spent During Space Walks?

# %%
space_walks["Space Walks (hr)"].max()
# Out:
# 67.0

# %% [markdown]
# #### Which Astronaut Spent the Most Time Performing Space Walks

# %%
most_time_space_walks = space_walks[space_walks["Space Walks (hr)"] == 67]

for name in most_time_space_walks["Name"]:
    print(name + ", was the astronaut that spent \
the most time during space walks.")
# Out:
# Michael E. Lopez-Alegria, was the astronaut that spent the most time during space walks.

# %% [markdown]
# #### What is the Average Amount of Time Spent Performing Space Walks?

# %%
round(space_walks["Space Walks (hr)"].mean(),2)
# Out:
# 20.38

# %% [markdown]
# #### Pivot Table for Space Walks and Space Walk (hr) based on Gender

# %%
pd.pivot_table(
    data = space_walks,
    index = "Gender", 
    values = ["Space Walks", "Space Walks (hr)"], 
    aggfunc = ["mean","median", "std"]
)
# Out:
#               mean                       median                          std  \
#        Space Walks Space Walks (hr) Space Walks Space Walks (hr) Space Walks
# Gender
# Female    2.727273        20.181818           2             13.0    2.240130
# Male      3.346774        20.399194           3             18.0    2.095463
#
#
#        Space Walks (hr)
# Gender
# Female        16.289986
# Male          14.564404

# %% [markdown]
# #### Boxplot based on Gender to Examine the Distribution and Identify Outliers

# %%
plt.figure(
    figsize = (12,8)
)
sns.boxplot(
    x = "Gender", 
    y = "Space Walks (hr)", 
    data = space_walks
)
plt.title("Distribution of Space walk Hours by Gender");

# %% [markdown]
# #### Histogram used to Examine the Distribution of Space Walks (hr)

# %%
sns.displot(
    space_walks["Space Walks (hr)"], 
    bins = 30, 
    color = "blue",
    height = 6,
    aspect = 1.5,
    alpha = 0.5
)
plt.axvline(
    np.mean(space_walks["Space Walks (hr)"]), 
    ls = "--", 
    label = "Mean", 
    color = "red"
)
plt.axvline(
    np.median(space_walks["Space Walks (hr)"]), 
    ls = ":", 
    label = "Median", 
    color = "green"
)
plt.legend()
plt.title("Distribution of Astronaut Space Walks (hr)");

# %% [markdown]
# #### Visualizing the Scatterplot of the Relationship between Space Flight (hr) and Space Walks (hr)

# %%
plt.figure(
    figsize = (12,10)
)

sns.scatterplot(
    data = space_walks, 
    x = "Space Flight (hr)", 
    y = "Space Walks (hr)", 
    hue = "Gender"
)
plt.title("Scatterplot for Space Flight (hr) vs Space Walks (hr)");

# %% [markdown]
# #### Visualizing the Relationship of Space Flight (hr) and Space Walks (hr)

# %%
sns.lmplot(
    x = "Space Flight (hr)", 
    y = "Space Walks (hr)", 
    data = space_walks, 
    hue = "Gender", 
    markers = ["o", "v"],
    height = 6,
    aspect = 1.5
)
plt.title("Scatterplot for Space Flight (hr) vs Space Walks (hr) with Trend Lines");

# %% [markdown]
# #### What is the Correlation between Space Flight (hr) and Space Walks (hr)?

# %%
space_walks["Space Flight (hr)"].corr(
    space_walks["Space Walks (hr)"]
)
# Out:
# 0.2595379056980412

# %% [markdown]
# ## <en><center>Multicollinearity</center></en>

# %% [markdown]
# ![Timber.png](attachment:fa6fc0de-8f34-45a5-a0a0-ca6d5e72bb3c.png)

# %% [markdown]
# ### Checking the Full Dataset Column Correlations for Multicollinearity.

# %%
df.corr()
# Out:
#                        Year     Group  Space Flights  Space Flight (hr)  \
# Year               1.000000  0.980934       0.036420           0.331386
# Group              0.980934  1.000000      -0.011386           0.325683
# Space Flights      0.036420 -0.011386       1.000000           0.325233
# Space Flight (hr)  0.331386  0.325683       0.325233           1.000000
# Space Walks        0.210073  0.217891       0.257073           0.472796
# Space Walks (hr)   0.253502  0.261384       0.258642           0.454408
#
#                    Space Walks  Space Walks (hr)
# Year                  0.210073          0.253502
# Group                 0.217891          0.261384
# Space Flights         0.257073          0.258642
# Space Flight (hr)     0.472796          0.454408
# Space Walks           1.000000          0.985755
# Space Walks (hr)      0.985755          1.000000

# %% [markdown]
# #### Visualizing the Full Dataset Correlation Matrix

# %%
plt.figure(
    figsize = (12,10)
)
astro_corr = df.corr()
sns.heatmap(
    astro_corr, 
    cmap = "magma", 
    linecolor = "black", 
    linewidths = 2, 
    annot = True
);

# %% [markdown]
# #### Correlation Matrix for Astronauts that have Performed at Least 1 Space Flight and Space Walk

# %%
space_walks.corr()
# Out:
#                        Year     Group  Space Flights  Space Flight (hr)  \
# Year               1.000000  0.980262       0.004708           0.399003
# Group              0.980262  1.000000      -0.046717           0.384600
# Space Flights      0.004708 -0.046717       1.000000           0.235222
# Space Flight (hr)  0.399003  0.384600       0.235222           1.000000
# Space Walks        0.305482  0.303513       0.333247           0.282853
# Space Walks (hr)   0.390494  0.389094       0.332081           0.259538
#
#                    Space Walks  Space Walks (hr)
# Year                  0.305482          0.390494
# Group                 0.303513          0.389094
# Space Flights         0.333247          0.332081
# Space Flight (hr)     0.282853          0.259538
# Space Walks           1.000000          0.970257
# Space Walks (hr)      0.970257          1.000000

# %% [markdown]
# #### Visualization of the Correlation Matrix for Astronauts that have Performed at Least 1 Space Walk and Space Flight

# %%
plt.figure(
    figsize = (12,10)
)

astro_corr = space_walks.corr()
sns.heatmap(
    astro_corr, 
    cmap = "magma", 
    linecolor = "black", 
    linewidths = 2, 
    annot = True
);

# %% [markdown]
# ## Key Insights

# %% [markdown]
# The numerical columns are not highly correlated.
#  - There is evidence for multicollinearity between columns "Group" and "Year", and "Space Walks" and "Space Walk (hr)".

# %% [markdown]
# 83% of astronauts possessed a graduate degree.

# %% [markdown]
# The top 10 undegraduate degrees were all in STEM fields.

# %% [markdown]
# Mosts astronauts served in the military with Colonel as the most common rank.

# %% [markdown]
# The most common Military Rank for men was Colonel, while for women it was Captain.

# %% [markdown]
# The most common number of space flights an astronaut performed was 2.

# %% [markdown]
# There were more male astronauts than female astronauts.
# - More men served in the military.
# - It is a dangerous profession as more men died in accidents.
# - Men performed more space walks.

# %% [markdown]
# #### Further Research is required:

# %% [markdown]
# Women on average spent more time in space.
# - Women generally have less muscle mass and lower bone density than men.
# - Women perhaps are more exposed to the detrimental physiological effects of microgravity.

# %% [markdown]
# # Thank you
